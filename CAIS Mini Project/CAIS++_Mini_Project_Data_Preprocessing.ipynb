# %%
import kagglehub

path = kagglehub.dataset_download("jainaru/thyroid-disease-data")

print("Path to Dataset", path)
# Out:
# ...
# 100%|██████████| 3.03k/3.03k [00:00<00:00, 5.60MB/s]
# Extracting files...
# Path to Dataset /root/.cache/kagglehub/datasets/jainaru/thyroid-disease-data/versions/1

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
data = pd.read_csv(path + '/Thyroid_Diff.csv')

# %%
data.head() #Testing DF Functionality
# Out:
#    Age Gender Smoking Hx Smoking Hx Radiothreapy Thyroid Function  \
# 0   27      F      No         No              No        Euthyroid
# 1   34      F      No        Yes              No        Euthyroid
# 2   30      F      No         No              No        Euthyroid
# 3   62      F      No         No              No        Euthyroid
# 4   62      F      No         No              No        Euthyroid
#
#           Physical Examination Adenopathy       Pathology     Focality Risk  \
# 0   Single nodular goiter-left         No  Micropapillary    Uni-Focal  Low
# 1          Multinodular goiter         No  Micropapillary    Uni-Focal  Low
# 2  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 3  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 4          Multinodular goiter         No  Micropapillary  Multi-Focal  Low
#
#      T   N   M Stage       Response Recurred
# 0  T1a  N0  M0     I  Indeterminate       No
# ...

# %%
data.isna().sum()
# Out:
# Age                     0
# Gender                  0
# Smoking                 0
# Hx Smoking              0
# Hx Radiothreapy         0
# Thyroid Function        0
# Physical Examination    0
# Adenopathy              0
# Pathology               0
# Focality                0
# Risk                    0
# T                       0
# N                       0
# M                       0
# Stage                   0
# Response                0
# Recurred                0
# dtype: int64

# %%
data.drop(columns = ['N', 'M', 'Stage', 'Response', 'Recurred'], axis = 1, inplace = True)

# %%
data
# Out:
#      Age Gender Smoking Hx Smoking Hx Radiothreapy          Thyroid Function  \
# 0     27      F      No         No              No                 Euthyroid
# 1     34      F      No        Yes              No                 Euthyroid
# 2     30      F      No         No              No                 Euthyroid
# 3     62      F      No         No              No                 Euthyroid
# 4     62      F      No         No              No                 Euthyroid
# ..   ...    ...     ...        ...             ...                       ...
# 378   72      M     Yes        Yes             Yes                 Euthyroid
# 379   81      M     Yes         No             Yes                 Euthyroid
# 380   72      M     Yes        Yes              No                 Euthyroid
# 381   61      M     Yes        Yes             Yes  Clinical Hyperthyroidism
# 382   67      M     Yes         No              No                 Euthyroid
#
# ...

# %%
data_dummies = pd.get_dummies(data.drop(['T'], axis = 1), drop_first=True)
data_dummies['T'] = data['T']
data_dummies.head()
# Out:
#    Age  Gender_M  Smoking_Yes  Hx Smoking_Yes  Hx Radiothreapy_Yes  \
# 0   27     False        False           False                False
# 1   34     False        False            True                False
# 2   30     False        False           False                False
# 3   62     False        False           False                False
# 4   62     False        False           False                False
#
#    Thyroid Function_Clinical Hypothyroidism  Thyroid Function_Euthyroid  \
# 0                                     False                        True
# 1                                     False                        True
# 2                                     False                        True
# 3                                     False                        True
# 4                                     False                        True
#
#    Thyroid Function_Subclinical Hyperthyroidism  \
# 0                                         False
# ...

# %%
data_dummies.to_csv('Thyroid_Diff_Cleaned.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
